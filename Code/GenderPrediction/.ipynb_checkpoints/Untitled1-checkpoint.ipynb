# %%
 l1=Label(self.frame,text="")
        l1.grid(row=2,column=0,sticky="wens")
        l2=Label(self.frame,text="")
        l2.grid(row=4,column=0,sticky="wens")
        l3=Label(self.frame,text="")
        l3.grid(row=6,column=0,sticky="wens")
        l4=Label(self.frame,text="")
        l4.grid(row=8,column=0,sticky="wens")
        l5=Label(self.frame,text="")
        l5.grid(row=10,column=0,sticky="wens")
        
        label1=Label(self.frame,text="Development of Children Gender Classification System Using Speech")
        label1.configure(fg="blue",font=("Helvetica", 18),anchor="center")
        label1.grid(row=12,column=0,sticky="wens")
       
        l6=Label(self.frame,text="")
        l6.grid(row=14,column=0,sticky="wens")
        l7=Label(self.frame,text="")
        l7.grid(row=16,column=0,sticky="wens")
        l8=Label(self.frame,text="")
        l8.grid(row=18,column=0,sticky="wens")
        l9=Label(self.frame,text="")
        l9.grid(row=20,column=0,sticky="wens")
        l10=Label(self.frame,text="")
        l10.grid(row=22,column=0,sticky="wens")
        l11=Label(self.frame,text="")
        l11.grid(row=24,column=0,sticky="wens")
        
        helv36 = font.Font(family='Helvetica', size=12, weight=font.BOLD)
        
        btn=Button(self.frame,text="Performance Analysis",command=self.openFrame,height=5,width=18,font=helv36,fg="blue")
        btn.grid(row=26,column=0)
        
        l13=Label(self.frame,text="")
        l13.grid(row=27,column=0,sticky="wens")
        l14=Label(self.frame,text="")
        l14.grid(row=28,column=0,sticky="wens")
        l15=Label(self.frame,text="")
        l15.grid(row=29,column=0,sticky="wens")
        l16=Label(self.frame,text="")
        l16.grid(row=30,column=0,sticky="wens")
        l17=Label(self.frame,text="")
        l17.grid(row=31,column=0,sticky="wens")
        
        btn1=Button(self.frame,text="Classification",command=self.showFrame,height=5,width=18,font=helv36,fg="blue")
        btn1.grid(row=40,column=0)
        
        l18=Label(self.frame,text="")
        l18.grid(row=42,column=0,sticky="wens")
        l19=Label(self.frame,text="")
        l19.grid(row=44,column=0,sticky="wens")
        l20=Label(self.frame,text="")
        l20.grid(row=46,column=0,sticky="wens")
        l22=Label(self.frame,text="")
        l22.grid(row=47,column=0,sticky="wens")
        l23=Label(self.frame,text="")
        l23.grid(row=48,column=0,sticky="wens")
        
        btn2=Button(self.frame,text="Exit",command=self.exitMain,height=5,width=18,font=helv36,fg="blue")
        btn2.grid(row=50,column=0)
        
        self.frame.pack()
